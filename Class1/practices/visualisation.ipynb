# %% [markdown]
# ## Visualization Libraries

# %% [markdown]
# Visualizations can be created in multiple ways:
#  - Matplotlib
#  - Pandas (via Matplotlib)
#  - Seaborn
#      - Statistically-focused plotting methods
#      - Global preferences incorporated by Matplotlib

# %% [markdown]
# ##### Basic scatter plots with matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# preparing data
import pandas as pd

filepath = '../data/Iris_Data.csv'
data = pd.read_csv(filepath)
print(data.iloc[:5])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Scatter plots using pandas series.

# %%
plt.plot(data.sepal_length, data.sepal_width, ls = '', marker = 'o')

# %% [markdown]
# Multiple layers of data can also be added

# %%
plt.plot(data.sepal_length, data.sepal_width, ls = '', marker = 'o', label = 'sepal')
plt.plot(data.petal_length, data.petal_width, ls = '', marker = 'o', label = 'petal')

# %% [markdown]
# ##### Histogram with matplotlib

# %%
plt.hist(data.sepal_length, bins = 25)
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# ##### Customizing matplotlib plots

# %% [markdown]
# Every feature of `matplotlib` plots can be customized.

# %%
fix, ax = plt.subplots()

# %%
import numpy as np

# %%
ax.barh(np.arange(10), data.sepal_width.iloc[:10])
# Out:
# <Container object of 10 artists>

# %%
# Set position of ticks and tick labels
ax.set_yticks(np.arange(0.4, 10.4, 1.0))
# Out:
# [<matplotlib.axis.YTick at 0x112698400>,
#  <matplotlib.axis.YTick at 0x1126987f0>,
#  <matplotlib.axis.YTick at 0x112721fd0>,
#  <matplotlib.axis.YTick at 0x11272b2b0>,
#  <matplotlib.axis.YTick at 0x11272b908>,
#  <matplotlib.axis.YTick at 0x11272bf60>,
#  <matplotlib.axis.YTick at 0x112731c50>,
#  <matplotlib.axis.YTick at 0x112698048>,
#  <matplotlib.axis.YTick at 0x1127c2ba8>,
#  <matplotlib.axis.YTick at 0x1127c8240>]

# %%
ax.set_yticklabels(np.arange(1, 11))
# Out:
# [Text(0,0,'1'),
#  Text(0,0.2,'2'),
#  Text(0,0.4,'3'),
#  Text(0,0.6,'4'),
#  Text(0,0.8,'5'),
#  Text(0,1,'6'),
#  Text(0,0,'7'),
#  Text(0,0,'8'),
#  Text(0,0,'9'),
#  Text(0,0,'10')]

# %%
ax.set(xlabel = 'xlabel', ylabel = 'ylabel', title = 'Title')
# Out:
# [Text(3.2,0.5,'ylabel'), Text(0.5,3.2,'xlabel'), Text(0.5,1,'Title')]

# %% [markdown]
# ##### Incorporating statistical calculations

# %% [markdown]
# Statistical calculations can be included with pandas methods.

# %%
(data.groupby('species').mean().plot(color = ['red', 'blue', 'black', 'green'], fontsize = 10.0, figsize = (4, 4)))

# %% [markdown]
# ##### Statistical plotting with seaborn

# %% [markdown]
# Joint distribution and scatter plots can be created.

# %%
import seaborn as sns

# %%
sns.jointplot(x = 'sepal_length', y = 'sepal_width', data = data, size = 4)

# %% [markdown]
# Correlation plots of all variable pairs can also be made with seaborn.

# %%
sns.pairplot(data, hue = 'species', size = 3)

# %% [markdown]
# ##### [GO BACK HOME](../../README.md)
